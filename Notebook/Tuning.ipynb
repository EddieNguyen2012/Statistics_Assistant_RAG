# %%
import src.Ingestion as Ingestion
import src.vector_db_utils as VDB
import src.pipeline as Pipeline

# %%
import pandas as pd

df = pd.read_csv('../evaluation.csv')
df.head()
# Out:
#                                             question  \
# 0                  What is the Law of Large Numbers?
# 1      How do permutations differ from combinations?
# 2  When would I use a Poisson distribution instea...
# 3  What is the memoryless property of the Exponen...
# 4  Define the expected value of a discrete random...
#
#                                             contexts  \
# 0  The Law of Large Numbers states that as a samp...
# 1  Permutations account for the exact order of se...
# 2  Use Poisson for counting events in a fixed int...
# 3  The probability of an event occurring in the f...
# 4  It is the probability-weighted average of all ...
#
#                                               answer  \
# 0  As a sample size grows, the sample mean conver...
# 1  Permutations account for order, while combinat...
# 2  Poisson is for events in a fixed interval; Bin...
# 3  Future event probability is independent of ela...
# ...
